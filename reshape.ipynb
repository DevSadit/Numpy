# %% [markdown]
# ## Reshape

# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3], [12, 14, 16], [8, 9, 10], [16, 20, 24]])
arr
# rarr = arr.reshape(3, 4)
# print(rarr.shape)
# Out:
# array([[ 1,  2,  3],
#        [12, 14, 16],
#        [ 8,  9, 10],
#        [16, 20, 24]])

# %%
rarr = arr.reshape(3, 4)
print(rarr)
# Out:
# [[ 1  2  3 12]
#  [14 16  8  9]
#  [10 16 20 24]]
