# %%
import numpy as np

# %% [markdown]
# <!-- Shape Management -->
#
# arr.shape
#
# arr.ndim
#
# arr.size
#
# arr.dtype

# %% [markdown]
# Practise

# %%
arr = np.array([[1,2,3],[12,14,16], [8,9,10]])
print(arr.shape)
print(arr.ndim) 
print(arr.size)
print(arr.dtype)
# Out:
# (3, 3)
# 2
# 9
# int64
