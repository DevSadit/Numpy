# %% [markdown]
# ## Practise
#
# ### Get scores ≥ 60
# ### Add 5 bonus marks to everyone
# ### Calculate the average
# ### Reshape into a 2×3 array

# %%
import numpy as np

# %%
scores = np.array([45, 60, 75, 30, 90, 55])

# %%
score60 = scores[scores>=60]
score60
# Out:
# array([60, 75, 90])

# %%
# 5 bonus mark
bonus = scores + 5
bonus
# Out:
# array([50, 65, 80, 35, 95, 60])

# %%
# average

mean = scores.mean()
mean
# Out:
# np.float64(59.166666666666664)

# %%
# reshape
reshape = scores.reshape(2,3)
reshape
# Out:
# array([[45, 60, 75],
#        [30, 90, 55]])
